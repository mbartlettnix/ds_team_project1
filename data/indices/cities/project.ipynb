# %%
import pandas as pd
import json
import requests as req
import csv
import numpy as np

# %%
csv_path='ds_team_project1/data/indices/ml_adjusted_ds_indices.csv'
o_df=pd.read_csv(csv_path)
new_all_df = o_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_all_df
# Out:
#               city  restaurant_price_index   cpi_index  rent_index  \
# 0        Cupertino               84.648271   81.802738   87.207894
# 1           Irvine               76.497712   83.723534   66.261200
# 2      Los Angeles               82.482643   82.331774   68.891009
# 3       Menlo Park               74.760254   96.900206  108.232276
# 4    Mountain View               81.646369   82.618190   87.003232
# 5        Palo Alto               74.760254   84.363586  108.232276
# 6        San Diego               82.094769   76.928217   61.885306
# 7    San Francisco               91.059461   97.926303  115.358705
# 8         San Jose               83.118394   82.954214   81.808630
# 9        San Mateo               82.185205   91.323950   83.481832
# 10     Santa Clara               80.949802   83.595653   77.781301
# 11    Santa Monica               96.642472   78.147692   99.212919
# 12       Sunnyvale               81.646369   80.278250   87.003232
# ...

# %%
city_list = new_all_df['city'].tolist()
#city_list

# %%
csv = city_list[0] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['restaurant_price_index','cpi_index','rent_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[0]]).mean().tolist()
df0 = pd.DataFrame({'city': city_list[0],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[0])
df0
# Out:
#         city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 0  Cupertino  80.397385        81.583037   72.875806               87.243631

# %%
csv = city_list[1] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['restaurant_price_index','cpi_index','rent_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[1]]).mean().tolist()
df1 = pd.DataFrame({'city': city_list[1],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[1])
df1
# Out:
#      city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 1  Irvine  89.492802        76.194413    56.28084                78.19898

# %%
csv = city_list[2] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[2]]).mean().tolist()
df2 = pd.DataFrame({'city': city_list[2],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[2])
df2
# Out:
#           city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 2  Los Angeles  78.000157        86.133244   58.824536               77.044407

# %%
csv = city_list[3] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[3]]).mean().tolist()
df3 = pd.DataFrame({'city': city_list[3],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[3])
df3
# Out:
#          city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 3  Menlo Park  89.816457        93.977449   74.335789               80.575389

# %%
csv = city_list[4] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[4]]).mean().tolist()
df4 = pd.DataFrame({'city': city_list[4],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[4])
df4
# Out:
#             city  cpi_index  groceries_index  rent_index  \
# 4  Mountain View  88.031205        92.168167   74.454696
#
#    restaurant_price_index
# 4               81.235487

# %%
csv = city_list[5] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[5]]).mean().tolist()
df5 = pd.DataFrame({'city': city_list[5],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[5])
df5
# Out:
#         city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 5  Palo Alto  88.249379        92.545359   74.698475               82.010727

# %%
csv = city_list[6] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[6]]).mean().tolist()
df6 = pd.DataFrame({'city': city_list[6],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[6])
df6
# Out:
#         city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 6  San Diego  62.446598        70.341332   43.984856               73.049624

# %%
csv = city_list[7] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[7]]).mean().tolist()
df7 = pd.DataFrame({'city': city_list[7],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[7])
df7
# Out:
#             city  cpi_index  groceries_index  rent_index  \
# 7  San Francisco  89.976776        91.680596   74.692788
#
#    restaurant_price_index
# 7               80.822524

# %%
csv = city_list[8] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[8]]).mean().tolist()
df8 = pd.DataFrame({'city': city_list[8],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[8])
df8
# Out:
#        city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 8  San Jose  87.371573        91.066061   72.682975               81.536677

# %%
csv = city_list[9] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[9]]).mean().tolist()
df9 = pd.DataFrame({'city': city_list[9],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[9])
df9
# Out:
#         city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 9  San Mateo  89.119425        90.770662   74.103965               80.616279

# %%
csv = city_list[10] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[10]]).mean().tolist()
df10 = pd.DataFrame({'city': city_list[10],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[10])
df10
# Out:
#            city  cpi_index  groceries_index  rent_index  \
# 10  Santa Clara  87.442844        91.066061   72.539142
#
#     restaurant_price_index
# 10               81.470962

# %%
csv = city_list[11] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[11]]).mean().tolist()
df11 = pd.DataFrame({'city': city_list[11],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[11])
df11
# Out:
#             city  cpi_index  groceries_index  rent_index  \
# 11  Santa Monica  77.547815        85.076501   60.078124
#
#     restaurant_price_index
# 11               77.102652

# %%
csv = city_list[12] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[12]]).mean().tolist()
df12 = pd.DataFrame({'city': city_list[12],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[12])
df12
# Out:
#          city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 12  Sunnyvale  87.738712         91.82284   74.454696               81.235487

# %%
csv = city_list[13] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[13]]).mean().tolist()
df13 = pd.DataFrame({'city': city_list[13],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[13])
df13
# Out:
#        city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 13  Boulder  78.815642        83.568113   49.111902               76.483971

# %%
csv = city_list[14] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[14]]).mean().tolist()
df14 = pd.DataFrame({'city': city_list[14],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[14])
df14
# Out:
#       city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 14  Denver  77.461746        82.244605   49.196896               76.752203

# %%
csv = city_list[15] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[15]]).mean().tolist()
df15 = pd.DataFrame({'city': city_list[15],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[15])
df15
# Out:
#           city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 15  Washington  90.288873        93.836346   49.001171                81.85148

# %%
csv = city_list[16] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[16]]).mean().tolist()
df16 = pd.DataFrame({'city': city_list[16],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[16])
df16
# Out:
#        city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 16  Atlanta  77.090357        77.718198    38.34028               68.854906

# %%
csv = city_list[17] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[17]]).mean().tolist()
df17 = pd.DataFrame({'city': city_list[17],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[17])
df17
# Out:
#        city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 17  Chicago  80.153564        72.080019   38.405697               70.241123

# %%
csv = city_list[18] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[18]]).mean().tolist()
df18 = pd.DataFrame({'city': city_list[18],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[18])
df18
# Out:
#             city  cpi_index  groceries_index  rent_index  \
# 18  Indianapolis  73.702173        77.090051   28.785403
#
#     restaurant_price_index
# 18                66.64775

# %%
csv = city_list[19] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[19]]).mean().tolist()
df19 = pd.DataFrame({'city': city_list[19],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[19])
df19
# Out:
#       city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 19  Boston  83.130098        88.514779   51.453236               78.680956

# %%
csv = city_list[20] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[20]]).mean().tolist()
df20 = pd.DataFrame({'city': city_list[20],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[20])
df20
# Out:
#          city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 20  Cambridge  81.884711        86.280762   49.447029               79.505881

# %%
csv = city_list[21] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[21]]).mean().tolist()
df21 = pd.DataFrame({'city': city_list[21],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[21])
df21
# Out:
#            city  cpi_index  groceries_index  rent_index  \
# 21  Kansas City  70.254155        71.094511   31.066225
#
#     restaurant_price_index
# 21               67.679811

# %%
csv = city_list[19] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[19]]).mean().tolist()
df19 = pd.DataFrame({'city': city_list[19],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[19])
df19
# Out:
#       city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 19  Boston  83.130098        88.514779   51.453236               78.680956

# %%
csv = city_list[22] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[22]]).mean().tolist()
df22 = pd.DataFrame({'city': city_list[22],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[22])
df22
# Out:
#          city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 22  St. Louis  70.759031        69.695064   24.833293               61.242228

# %%
csv = city_list[23] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[23]]).mean().tolist()
df23 = pd.DataFrame({'city': city_list[23],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[23])
df23
# Out:
#            city  cpi_index  groceries_index  rent_index  \
# 23  Minneapolis  80.433456        85.709127   38.807489
#
#     restaurant_price_index
# 23               72.439484

# %%
csv = city_list[24] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[24]]).mean().tolist()
df24 = pd.DataFrame({'city': city_list[24],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[24])
df24
# Out:
#          city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 24  Charlotte  75.350432        82.097416    32.96131                62.56364

# %%
csv = city_list[25] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[25]]).mean().tolist()
df25 = pd.DataFrame({'city': city_list[25],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[25])
df25
# Out:
#        city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 25  Raleigh  69.745503        78.483585   32.978484                80.26645

# %%
csv = city_list[26] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[26]]).mean().tolist()
df26 = pd.DataFrame({'city': city_list[26],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[26])
df26
# Out:
#         city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 26  New York  89.345361        86.298283   60.012262               93.510587

# %%
csv = city_list[27] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[27]]).mean().tolist()
df27 = pd.DataFrame({'city': city_list[27],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[27])
df27
# Out:
#           city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 27  Cincinnati  69.337634        65.578179   28.061899                79.06593

# %%
csv = city_list[28] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[28]]).mean().tolist()
df28 = pd.DataFrame({'city': city_list[28],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[28])
df28
# Out:
#          city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 28  Cleveland  73.195953        77.217366   20.844567               70.440129

# %%
csv = city_list[29] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[29]]).mean().tolist()
df29 = pd.DataFrame({'city': city_list[29],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[29])
df29
# Out:
#         city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 29  Portland  74.425089         74.66146   39.231291               66.743408

# %%
csv = city_list[30] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[30]]).mean().tolist()
df30 = pd.DataFrame({'city': city_list[30],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[30])
df30
# Out:
#             city  cpi_index  groceries_index  rent_index  \
# 30  Philadelphia  81.200002         78.29918    42.82979
#
#     restaurant_price_index
# 30               78.183653

# %%
csv = city_list[31] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[31]]).mean().tolist()
df31 = pd.DataFrame({'city': city_list[31],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[31])
df31
# Out:
#       city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 31  Austin  72.457977        68.405718   36.047757                64.66944

# %%
csv = city_list[32] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[32]]).mean().tolist()
df32 = pd.DataFrame({'city': city_list[32],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[32])
df32
# Out:
#       city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 32  Dallas  68.870081        68.488081   32.733576               65.833565

# %%
csv = city_list[33] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[33]]).mean().tolist()
df33 = pd.DataFrame({'city': city_list[33],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[33])
df33
# Out:
#        city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 33  Houston  79.022709        85.966438   41.244472               73.657618

# %%
csv = city_list[34] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[34]]).mean().tolist()
df34 = pd.DataFrame({'city': city_list[34],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[34])
df34
# Out:
#          city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 34  Nashville  71.873793        74.540752   34.919225               64.385727

# %%
csv = city_list[35] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[35]]).mean().tolist()
df35 = pd.DataFrame({'city': city_list[35],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[35])
df35
# Out:
#      city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 35  Plano  70.428975        70.200123   32.472845               65.531939

# %%
csv = city_list[36] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[36]]).mean().tolist()
df36 = pd.DataFrame({'city': city_list[36],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[36])
df36
# Out:
#               city  cpi_index  groceries_index  rent_index  \
# 36  Salt Lake City  66.756199        63.369249   28.313613
#
#     restaurant_price_index
# 36               67.669293

# %%
csv = city_list[37] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[37]]).mean().tolist()
df37 = pd.DataFrame({'city': city_list[37],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[37])
df37
# Out:
#       city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 37  McLean  89.459604        90.999141   46.809601               81.164883

# %%
csv = city_list[38] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[38]]).mean().tolist()
df38 = pd.DataFrame({'city': city_list[38],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[38])
df38
# Out:
#       city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 38  Reston  92.856903        94.339249   47.752368               81.335266

# %%
csv = city_list[39] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[39]]).mean().tolist()
df39 = pd.DataFrame({'city': city_list[39],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[39])
df39
# Out:
#         city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 39  Richmond  70.981286        75.067668   34.345224               72.853065

# %%
csv = city_list[40] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[40]]).mean().tolist()
df40 = pd.DataFrame({'city': city_list[40],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[40])
df40
# Out:
#         city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 40  Bellevue  84.817357        89.019226   43.472161               77.359033

# %%
csv = city_list[41] + '_ds_indices.csv'
csv_path='ds_team_project1/data/indices/nearby_cities/' + csv
city_df=pd.read_csv(csv_path)
new_df = city_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[41]]).mean().tolist()
df41 = pd.DataFrame({'city': city_list[41],
                    'restaurant_price_index':new_list[0],
                    'cpi_index':new_list[1],
                    'rent_index':new_list[2],
                    'groceries_index':new_list[3]},index=[41])
df41
# Out:
#        city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 41  Seattle  84.343268        88.691158   43.135382               79.775887

# %%
c_df = df0.append(df1).append(df2).append(df3).append(df4).append(df5).append(df6).append(df7).append(df8).append(df9).append(df10).append(df11).append(df12).append(df13).append(df14).append(df15).append(df16).append(df18).append(df19).append(df20).append(df21).append(df22).append(df23).append(df24).append(df25).append(df26).append(df27).append(df28).append(df29).append(df30).append(df31).append(df32).append(df33).append(df34).append(df35).append(df36).append(df37).append(df38).append(df39).append(df40).append(df41)
c_df
# Out:
#               city  cpi_index  groceries_index  rent_index  \
# 0        Cupertino  80.397385        81.583037   72.875806
# 1           Irvine  89.492802        76.194413   56.280840
# 2      Los Angeles  78.000157        86.133244   58.824536
# 3       Menlo Park  89.816457        93.977449   74.335789
# 4    Mountain View  88.031205        92.168167   74.454696
# 5        Palo Alto  88.249379        92.545359   74.698475
# 6        San Diego  62.446598        70.341332   43.984856
# 7    San Francisco  89.976776        91.680596   74.692788
# 8         San Jose  87.371573        91.066061   72.682975
# 9        San Mateo  89.119425        90.770662   74.103965
# 10     Santa Clara  87.442844        91.066061   72.539142
# 11    Santa Monica  77.547815        85.076501   60.078124
# 12       Sunnyvale  87.738712        91.822840   74.454696
# 13         Boulder  78.815642        83.568113   49.111902
# 14          Denver  77.461746        82.244605   49.196896
# ...

# %%
c_df['cpi_single']=c_df['cpi_index']/100*1957.34
c_df['cpi_family']=c_df['cpi_index']/100*5699.47
c_df['rent_single']=c_df['rent_index']/100*(3096.05+1886.53)/2
c_df['rent_family']=c_df['rent_index']/100*(6017.17+3321.3)/2
c_df['groceries_single']=c_df['groceries_index']/100*283.69
c_df['groceries_family']=c_df['groceries_index']/100*1418.43 
c_df['restaurant_single']=c_df['restaurant_price_index']/100*795.83 
c_df['restaurant_family']=c_df['restaurant_price_index']/100*2365.20
c_df['occupation']=salary_df['occupation']
c_df['salary']=salary_df['base_salary_md_pay']
c_df['col_single']= c_df['cpi_single'] + c_df['rent_single']
c_df['col_family']= c_df['cpi_family'] + c_df['rent_family']
c_df['ds_single']= salary_df['base_salary_md_pay']/12 - c_df['col_single']
c_df['ds_family']= salary_df['base_salary_md_pay']/12 - c_df['col_family']

# %%
c_df['state'] = o_df['state']
new_c_df = c_df[['state','city','occupation','salary','cpi_index','rent_index','restaurant_price_index','groceries_index','cpi_single','cpi_family','rent_single','rent_family','groceries_single','groceries_family','restaurant_single','restaurant_family','col_single','col_family','ds_single','ds_family']]
new_c_df
# Out:
#                    state            city          occupation     salary  \
# 0             California       Cupertino  Data Scientist, IT  125000.00
# 1             California          Irvine  Data Scientist, IT   85295.36
# 2             California     Los Angeles  Data Scientist, IT   86269.74
# 3             California      Menlo Park  Data Scientist, IT   86400.00
# 4             California   Mountain View  Data Scientist, IT  103042.00
# 5             California       Palo Alto  Data Scientist, IT  114109.51
# 6             California       San Diego  Data Scientist, IT   91324.00
# 7             California   San Francisco  Data Scientist, IT  114060.42
# 8             California        San Jose  Data Scientist, IT  117109.79
# 9             California       San Mateo  Data Scientist, IT  104804.68
# 10            California     Santa Clara  Data Scientist, IT  109926.79
# 11            California    Santa Monica  Data Scientist, IT   88988.76
# ...

# %%
csv_path='ds_team_project1/data/salary/payscale_ds_salary.csv'
salary_df=pd.read_csv(csv_path)
salary_df
# Out:
#     Unnamed: 0          occupation                 state            city  \
# 0            0  Data Scientist, IT            California       Cupertino
# 1            1  Data Scientist, IT            California          Irvine
# 2            2  Data Scientist, IT            California     Los Angeles
# 3            3  Data Scientist, IT            California      Menlo Park
# 4            4  Data Scientist, IT            California   Mountain View
# 5            5  Data Scientist, IT            California       Palo Alto
# 6            6  Data Scientist, IT            California       San Diego
# 7            7  Data Scientist, IT            California   San Francisco
# 8            8  Data Scientist, IT            California        San Jose
# 9            9  Data Scientist, IT            California       San Mateo
# 10          10  Data Scientist, IT            California     Santa Clara
# 11          11  Data Scientist, IT            California    Santa Monica
# ...

# %%
top10_df=new_c_df.nlargest(10,'salary')
top10_df
# Out:
#          state           city          occupation     salary  cpi_index  \
# 0   California      Cupertino  Data Scientist, IT  125000.00  80.397385
# 8   California       San Jose  Data Scientist, IT  117109.79  87.371573
# 5   California      Palo Alto  Data Scientist, IT  114109.51  88.249379
# 7   California  San Francisco  Data Scientist, IT  114060.42  89.976776
# 40  Washington       Bellevue  Data Scientist, IT  111968.75  84.817357
# 10  California    Santa Clara  Data Scientist, IT  109926.79  87.442844
# 9   California      San Mateo  Data Scientist, IT  104804.68  89.119425
# 4   California  Mountain View  Data Scientist, IT  103042.00  88.031205
# 41  Washington        Seattle  Data Scientist, IT  100529.55  84.343268
# 26    New York       New York  Data Scientist, IT   99199.95  89.345361
#
#     rent_index  restaurant_price_index  groceries_index   cpi_single  \
# 0    72.875806               87.243631        81.583037  1573.650179
# ...

# %%
new_c_df.to_csv('ds_team_project1/data/indices/converted_indices1.csv')
top10_df.to_csv('ds_team_project1/data/indices/top10_indices1.csv')

# %%
c1_df = df0.append(df1).append(df2).append(df3).append(df4).append(df5).append(df6).append(df7).append(df8).append(df9).append(df10).append(df11).append(df12).append(df13).append(df14).append(df15).append(df16).append(df18).append(df19).append(df20).append(df21).append(df22).append(df23).append(df24).append(df25).append(df26).append(df27).append(df28).append(df29).append(df30).append(df31).append(df32).append(df33).append(df34).append(df35).append(df36).append(df37).append(df38).append(df39).append(df40).append(df41)
c1_df
# Out:
#               city  cpi_index  groceries_index  rent_index  \
# 0        Cupertino  80.397385        81.583037   72.875806
# 1           Irvine  89.492802        76.194413   56.280840
# 2      Los Angeles  78.000157        86.133244   58.824536
# 3       Menlo Park  89.816457        93.977449   74.335789
# 4    Mountain View  88.031205        92.168167   74.454696
# 5        Palo Alto  88.249379        92.545359   74.698475
# 6        San Diego  62.446598        70.341332   43.984856
# 7    San Francisco  89.976776        91.680596   74.692788
# 8         San Jose  87.371573        91.066061   72.682975
# 9        San Mateo  89.119425        90.770662   74.103965
# 10     Santa Clara  87.442844        91.066061   72.539142
# 11    Santa Monica  77.547815        85.076501   60.078124
# 12       Sunnyvale  87.738712        91.822840   74.454696
# 13         Boulder  78.815642        83.568113   49.111902
# 14          Denver  77.461746        82.244605   49.196896
# ...

# %%
c1_df['cpi_single']=c1_df['cpi_index']/78.000157*1760.35
c1_df['cpi_family']=c1_df['cpi_index']/78.000157*4791.38
c1_df['rent_single']=c1_df['rent_index']/58.824536*(2075.33+1582.08)/2
c1_df['rent_family']=c1_df['rent_index']/58.824536*(3466.02+2722.98)/2
c1_df['groceries_single']=c1_df['groceries_index']/86.133244*241.80
c1_df['groceries_family']=c1_df['groceries_index']/86.133244*1209.02
c1_df['restaurant_single']=c1_df['restaurant_price_index']/77.044407*667.70
c1_df['restaurant_family']=c1_df['restaurant_price_index']/77.044407*1877.15
c1_df['occupation']=salary_df['occupation']
c1_df['salary']=salary_df['base_salary_md_pay']
c1_df['col_single']= c1_df['cpi_single'] + c1_df['rent_single']
c1_df['col_family']= c1_df['cpi_family'] + c1_df['rent_family']
c1_df['ds_single']= salary_df['base_salary_md_pay']/12 - c1_df['col_single']
c1_df['ds_family']= salary_df['base_salary_md_pay']/12 - c1_df['col_family']

# %%
c1_df['state'] = o_df['state']
new_c1_df = c1_df[['state','city','occupation','salary','cpi_index','rent_index','restaurant_price_index','groceries_index','cpi_single','cpi_family','rent_single','rent_family','groceries_single','groceries_family','restaurant_single','restaurant_family','col_single','col_family','ds_single','ds_family']]
new_c1_df
# Out:
#                    state            city          occupation     salary  \
# 0             California       Cupertino  Data Scientist, IT  125000.00
# 1             California          Irvine  Data Scientist, IT   85295.36
# 2             California     Los Angeles  Data Scientist, IT   86269.74
# 3             California      Menlo Park  Data Scientist, IT   86400.00
# 4             California   Mountain View  Data Scientist, IT  103042.00
# 5             California       Palo Alto  Data Scientist, IT  114109.51
# 6             California       San Diego  Data Scientist, IT   91324.00
# 7             California   San Francisco  Data Scientist, IT  114060.42
# 8             California        San Jose  Data Scientist, IT  117109.79
# 9             California       San Mateo  Data Scientist, IT  104804.68
# 10            California     Santa Clara  Data Scientist, IT  109926.79
# 11            California    Santa Monica  Data Scientist, IT   88988.76
# ...

# %%
csv_path='ds_team_project1/data/salary/payscale_ds_salary.csv'
salary_df=pd.read_csv(csv_path)
salary_df
# Out:
#     Unnamed: 0          occupation                 state            city  \
# 0            0  Data Scientist, IT            California       Cupertino
# 1            1  Data Scientist, IT            California          Irvine
# 2            2  Data Scientist, IT            California     Los Angeles
# 3            3  Data Scientist, IT            California      Menlo Park
# 4            4  Data Scientist, IT            California   Mountain View
# 5            5  Data Scientist, IT            California       Palo Alto
# 6            6  Data Scientist, IT            California       San Diego
# 7            7  Data Scientist, IT            California   San Francisco
# 8            8  Data Scientist, IT            California        San Jose
# 9            9  Data Scientist, IT            California       San Mateo
# 10          10  Data Scientist, IT            California     Santa Clara
# 11          11  Data Scientist, IT            California    Santa Monica
# ...

# %%
top10_df=new_c1_df.nlargest(10,'salary')
top10_df
# Out:
#          state           city          occupation     salary  cpi_index  \
# 0   California      Cupertino  Data Scientist, IT  125000.00  80.397385
# 8   California       San Jose  Data Scientist, IT  117109.79  87.371573
# 5   California      Palo Alto  Data Scientist, IT  114109.51  88.249379
# 7   California  San Francisco  Data Scientist, IT  114060.42  89.976776
# 40  Washington       Bellevue  Data Scientist, IT  111968.75  84.817357
# 10  California    Santa Clara  Data Scientist, IT  109926.79  87.442844
# 9   California      San Mateo  Data Scientist, IT  104804.68  89.119425
# 4   California  Mountain View  Data Scientist, IT  103042.00  88.031205
# 41  Washington        Seattle  Data Scientist, IT  100529.55  84.343268
# 26    New York       New York  Data Scientist, IT   99199.95  89.345361
#
#     rent_index  restaurant_price_index  groceries_index   cpi_single  \
# 0    72.875806               87.243631        81.583037  1814.451950
# ...

# %%
new_c1_df.to_csv('ds_team_project1/data/indices/converted_indices_la.csv')
top10_df.to_csv('ds_team_project1/data/indices/top10_indices_la.csv')
