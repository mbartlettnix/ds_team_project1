# %%
import pandas as pd
import json
import requests as req
import csv
import numpy as np

# %%
csv_path='ds_team_project1/data/indices/ml_adjusted_ds_indices.csv'
o_df = pd.read_csv(csv_path)
new_all_df = o_df[['city','restaurant_price_index','cpi_index','rent_index','groceries_index']]
new_all_df
# Out:
#               city  restaurant_price_index   cpi_index  rent_index  \
# 0        Cupertino               84.648271   81.802738   87.207894
# 1           Irvine               76.497712   83.723534   66.261200
# 2      Los Angeles               82.482643   82.331774   68.891009
# 3       Menlo Park               74.760254   96.900206  108.232276
# 4    Mountain View               81.646369   82.618190   87.003232
# 5        Palo Alto               74.760254   84.363586  108.232276
# 6        San Diego               82.094769   76.928217   61.885306
# 7    San Francisco               91.059461   97.926303  115.358705
# 8         San Jose               83.118394   82.954214   81.808630
# 9        San Mateo               82.185205   91.323950   83.481832
# 10     Santa Clara               80.949802   83.595653   77.781301
# 11    Santa Monica               96.642472   78.147692   99.212919
# 12       Sunnyvale               81.646369   80.278250   87.003232
# 13         Boulder               74.915180   82.189049   53.798052
# 14          Denver               78.133960   76.773466   54.647992
# 15      Washington               84.998308   91.935729   73.295732
# 16         Atlanta               74.814042   75.052731   45.951221
# 17         Chicago               77.987858   80.151981   56.705775
# 18    Indianapolis               74.259289   74.912810   35.707660
# 19          Boston               86.203184   87.228420   78.720632
# 20       Cambridge               94.856407   82.246874   46.931550
# 21     Kansas City               63.041035   69.074253   29.328867
# 22       St. Louis               68.144523   70.757634   30.105249
# 23     Minneapolis               75.879686   81.469180   45.822136
# 24       Charlotte               73.872105   75.348944   40.623034
# 25         Raleigh               70.579763   71.397522   37.423620
# 26        New York              100.000000  100.000000  100.000000
# 27      Cincinnati               70.398877   69.123909   31.112955
# 28       Cleveland               74.695435   73.465646   28.346229
# 29        Portland               68.386995   78.463665   51.720518
# 30    Philadelphia               79.365579   83.451932   48.092975
# 31          Austin               75.563423   72.456546   49.804624
# 32          Dallas               67.106772   65.968495   43.149358
# 33         Houston               70.036625   70.186328   43.969720
# 34       Nashville               69.378218   71.872374   47.726363
# 35           Plano               63.487267   75.321859   40.020588
# 36  Salt Lake City               68.754168   66.754881   34.911143
# 37          McLean               78.112309   84.472313   53.548581
# 38          Reston               74.951783  109.807213   57.061685
# 39        Richmond               65.735637   70.979885   36.180033
# 40        Bellevue               80.987509   90.775682   66.669336
# 41         Seattle               82.713729   87.931149   64.410733
#
#     groceries_index
# 0         80.397385
# 1         89.492802
# 2         82.725730
# 3        111.718750
# 4         84.579527
# 5         90.237399
# 6         75.085481
# 7        107.518685
# 8         85.401811
# 9         95.144770
# 10        85.401811
# 11        77.005219
# 12        79.399622
# 13        86.224150
# 14        76.959597
# 15        92.740945
# 16        75.001183
# 17        79.139436
# 18        73.919490
# 19        88.990334
# 20        66.650158
# 21        68.172036
# 22        71.329323
# 23        87.476657
# 24        79.398541
# 25        78.319607
# 26       100.000000
# 27        61.601019
# 28        67.518833
# 29        79.563872
# 30        82.236531
# 31        73.024519
# 32        61.948626
# 33        71.081168
# 34        74.280111
# 35        73.932922
# 36        64.475421
# 37        88.281250
# 38       133.415107
# 39        77.659940
# 40        92.472031
# 41        89.847485

# %%
city_list = new_all_df['city'].tolist()
#city_list

# %%
def ds(num):
  csv = city_list[num] + '_ds_indices.csv'
  csv_path = 'ds_team_project1/data/indices/nearby_cities/' + csv
  city_df = pd.read_csv(csv_path)
  new_df = city_df[['restaurant_price_index','cpi_index','rent_index', 'groceries_index']]
  new_list = new_df.append(new_all_df.loc[new_all_df['city'] == city_list[num]]).mean().tolist()
  df = pd.DataFrame({'city': city_list[num],
                  'restaurant_price_index':new_list[0],
                  'cpi_index':new_list[1],
                  'rent_index':new_list[2],
                  'groceries_index':new_list[3]},index=[num])
  return df
ds(0)
# Out:
#         city  cpi_index  groceries_index  rent_index  restaurant_price_index
# 0  Cupertino  90.771683        81.583037   72.875806               87.243631

# %%
c_df = ds(0).append(ds(1)).append(ds(2)).append(ds(3)).append(ds(4)).append(ds(5)).append(ds(6)).append(ds(7)).append(ds(8)).append(ds(9)).append(ds(10)).append(ds(11)).append(ds(12)).append(ds(13)).append(ds(14)).append(ds(15)).append(ds(16)).append(ds(17)).append(ds(18)).append(ds(19)).append(ds(20)).append(ds(21)).append(ds(22)).append(ds(23)).append(ds(24)).append(ds(25)).append(ds(26)).append(ds(27)).append(ds(28)).append(ds(29)).append(ds(30)).append(ds(31)).append(ds(32)).append(ds(33)).append(ds(34)).append(ds(35)).append(ds(36)).append(ds(37)).append(ds(38)).append(ds(39)).append(ds(40)).append(ds(41))
c_df
# Out:
#               city  cpi_index  groceries_index  rent_index  \
# 0        Cupertino  90.771683        81.583037   72.875806
# 1           Irvine  82.386102        76.194413   56.280840
# 2      Los Angeles  86.133244        77.044407   58.824536
# 3       Menlo Park  93.977449        80.575389   74.335789
# 4    Mountain View  92.168167        81.235487   74.454696
# 5        Palo Alto  92.545359        82.010727   74.698475
# 6        San Diego  70.341332        73.049624   43.984856
# 7    San Francisco  91.680596        80.822524   74.692788
# 8         San Jose  91.066061        81.536677   72.682975
# 9        San Mateo  90.770662        80.616279   74.103965
# 10     Santa Clara  91.066061        81.470962   72.539142
# 11    Santa Monica  85.076501        77.102652   60.078124
# 12       Sunnyvale  91.822840        81.235487   74.454696
# 13         Boulder  83.568113        76.483971   49.111902
# 14          Denver  82.244605        76.752203   49.196896
# 15      Washington  93.836346        81.851480   49.001171
# 16         Atlanta  77.718198        68.854906   38.340280
# 17         Chicago  72.080019        70.241123   38.405697
# 18    Indianapolis  77.090051        66.647750   28.785403
# 19          Boston  88.514779        78.680956   51.453236
# 20       Cambridge  86.280762        79.505881   49.447029
# 21     Kansas City  71.094511        67.679811   31.066225
# 22       St. Louis  69.695064        61.242228   24.833293
# 23     Minneapolis  85.709127        72.439484   38.807489
# 24       Charlotte  82.097416        62.563640   32.961310
# 25         Raleigh  78.483585        80.266450   32.978484
# 26        New York  86.298283        93.510587   60.012262
# 27      Cincinnati  65.578179        79.065930   28.061899
# 28       Cleveland  77.217366        70.440129   20.844567
# 29        Portland  74.661460        66.743408   39.231291
# 30    Philadelphia  78.299180        78.183653   42.829790
# 31          Austin  68.405718        64.669440   36.047757
# 32          Dallas  68.488081        65.833565   32.733576
# 33         Houston  85.966438        73.657618   41.244472
# 34       Nashville  74.540752        64.385727   34.919225
# 35           Plano  70.200123        65.531939   32.472845
# 36  Salt Lake City  63.369249        67.669293   28.313613
# 37          McLean  90.999141        81.164883   46.809601
# 38          Reston  94.339249        81.335266   47.752368
# 39        Richmond  75.067668        72.853065   34.345224
# 40        Bellevue  89.019226        77.359033   43.472161
# 41         Seattle  88.691158        79.775887   43.135382
#
#     restaurant_price_index
# 0                87.243631
# 1                78.198980
# 2                78.000157
# 3                89.816457
# 4                88.031205
# 5                88.249379
# 6                62.446598
# 7                89.976776
# 8                87.371573
# 9                89.119425
# 10               87.442844
# 11               77.547815
# 12               87.738712
# 13               78.815642
# 14               77.461746
# 15               90.288873
# 16               77.090357
# 17               80.153564
# 18               73.702173
# 19               83.130098
# 20               81.884711
# 21               70.254155
# 22               70.759031
# 23               80.433456
# 24               75.350432
# 25               69.745503
# 26               89.345361
# 27               69.337634
# 28               73.195953
# 29               74.425089
# 30               81.200002
# 31               72.457977
# 32               68.870081
# 33               79.022709
# 34               71.873793
# 35               70.428975
# 36               66.756199
# 37               89.459604
# 38               92.856903
# 39               70.981286
# 40               84.817357
# 41               84.343268

# %%
c_df['cpi_single']=c_df['cpi_index']/100*1957.34
c_df['cpi_family']=c_df['cpi_index']/100*5699.47
c_df['rent_single']=c_df['rent_index']/100*(3096.05+1886.53)/2
c_df['rent_family']=c_df['rent_index']/100*(6017.17+3321.3)/2
c_df['groceries_single']=c_df['groceries_index']/100*283.69
c_df['groceries_family']=c_df['groceries_index']/100*1418.43 
c_df['restaurant_single']=c_df['restaurant_price_index']/100*795.83 
c_df['restaurant_family']=c_df['restaurant_price_index']/100*2365.20
c_df['occupation']=salary_df['occupation']
c_df['salary']=salary_df['base_salary_md_pay']
c_df['col_single']= c_df['cpi_single'] + c_df['rent_single']
c_df['col_family']= c_df['cpi_family'] + c_df['rent_family']
c_df['ds_single']= salary_df['base_salary_md_pay']/12 - c_df['col_single']
c_df['ds_family']= salary_df['base_salary_md_pay']/12 - c_df['col_family']

# %%
c_df['state'] = o_df['state']
new_c_df = c_df[['state','city','occupation','salary','cpi_index','rent_index','restaurant_price_index','groceries_index','cpi_single','cpi_family','rent_single','rent_family','groceries_single','groceries_family','restaurant_single','restaurant_family']]
new_c_df.head()
# Out:
#         state           city          occupation     salary  cpi_index  \
# 0  California      Cupertino  Data Scientist, IT  125000.00  90.771683
# 1  California         Irvine  Data Scientist, IT   85295.36  82.386102
# 2  California    Los Angeles  Data Scientist, IT   86269.74  86.133244
# 3  California     Menlo Park  Data Scientist, IT   86400.00  93.977449
# 4  California  Mountain View  Data Scientist, IT  103042.00  92.168167
#
#    rent_index  restaurant_price_index  groceries_index   cpi_single  \
# 0   72.875806               87.243631        81.583037  1776.710454
# 1   56.280840               78.198980        76.194413  1612.576128
# 2   58.824536               78.000157        77.044407  1685.920447
# 3   74.335789               89.816457        80.575389  1839.458193
# 4   74.454696               88.031205        81.235487  1804.044402
#
#     cpi_family  rent_single  rent_family  groceries_single  groceries_family  \
# 0  5173.504824  1815.547656  3402.742620        231.442916       1157.198266
# 1  4695.571164  1402.118943  2627.884687        216.155931       1080.764418
# 2  4909.138427  1465.489775  2746.655808        218.567279       1092.820987
# 3  5356.216490  1851.920076  3470.912674        228.584322       1142.905493
# 4  5253.097034  1854.882407  3476.464745        230.456952       1152.268515
#
#    restaurant_single  restaurant_family
# 0         694.310990        2063.486363
# 1         622.330939        1849.562264
# 2         620.748647        1844.859706
# 3         714.786308        2124.338837
# 4         700.578737        2082.114056

# %%
csv_path='ds_team_project1/data/salary/payscale_ds_salary.csv'
salary_df=pd.read_csv(csv_path)
salary_df.head()
# Out:
#    Unnamed: 0          occupation       state           city  \
# 0           0  Data Scientist, IT  California      Cupertino
# 1           1  Data Scientist, IT  California         Irvine
# 2           2  Data Scientist, IT  California    Los Angeles
# 3           3  Data Scientist, IT  California     Menlo Park
# 4           4  Data Scientist, IT  California  Mountain View
#
#    total_cash_comp_md_pay  base_salary_md_pay  bonus_md_pay  sample_size  \
# 0               130000.00           125000.00      14000.00            6
# 1                86955.19            85295.36       7500.00           16
# 2                85000.05            86269.74       4000.00           24
# 3                86400.00            86400.00      13265.57            5
# 4               114650.24           103042.00       9932.93           28
#
#                        last_reviewed
# 0  2018-01-10T14:56:09.8427599-08:00
# 1  2018-01-05T02:53:31.5132805-08:00
# 2  2018-01-10T14:46:11.6752289-08:00
# 3  2018-01-04T06:30:44.8894913-08:00
# 4  2018-01-10T14:46:32.5088419-08:00

# %%
top10_df=new_c_df.nlargest(10,'salary')
top10_df
# Out:
#          state           city          occupation     salary  cpi_index  \
# 0   California      Cupertino  Data Scientist, IT  125000.00  90.771683
# 8   California       San Jose  Data Scientist, IT  117109.79  91.066061
# 5   California      Palo Alto  Data Scientist, IT  114109.51  92.545359
# 7   California  San Francisco  Data Scientist, IT  114060.42  91.680596
# 40  Washington       Bellevue  Data Scientist, IT  111968.75  89.019226
# 10  California    Santa Clara  Data Scientist, IT  109926.79  91.066061
# 9   California      San Mateo  Data Scientist, IT  104804.68  90.770662
# 4   California  Mountain View  Data Scientist, IT  103042.00  92.168167
# 41  Washington        Seattle  Data Scientist, IT  100529.55  88.691158
# 26    New York       New York  Data Scientist, IT   99199.95  86.298283
#
#     rent_index  restaurant_price_index  groceries_index   cpi_single  \
# 0    72.875806               87.243631        81.583037  1776.710454
# 8    72.682975               87.371573        81.536677  1782.472433
# 5    74.698475               88.249379        82.010727  1811.427321
# 7    74.692788               89.976776        80.822524  1794.500986
# 40   43.472161               84.817357        77.359033  1742.408915
# 10   72.539142               87.442844        81.470962  1782.472433
# 9    74.103965               89.119425        80.616279  1776.690468
# 4    74.454696               88.031205        81.235487  1804.044402
# 41   43.135382               84.343268        79.775887  1735.987507
# 26   60.012262               89.345361        93.510587  1689.150805
#
#      cpi_family  rent_single  rent_family  groceries_single  groceries_family  \
# 0   5173.504824  1815.547656  3402.742620        231.442916       1157.198266
# 8   5190.282810  1810.743680  3393.738894        231.311398       1156.540683
# 5   5274.594947  1860.955641  3487.847345        232.656232       1163.264758
# 7   5225.308088  1860.813960  3487.581803        229.285419       1146.410928
# 40  5073.624072  1083.017609  2029.817374        219.459841       1097.283734
# 10  5190.282810  1807.160379  3387.022984        231.124971       1155.608563
# 9   5173.446628  1846.144668  3460.088267        228.700323       1143.485493
# 4   5253.097034  1854.882407  3476.464745        230.456952       1152.268515
# 41  5054.925927  1074.627452  2014.092342        226.316214       1131.565113
# 26  4918.544729  1495.079474  2802.113526        265.280184       1326.382217
#
#     restaurant_single  restaurant_family
# 0          694.310990        2063.486363
# 8          695.329189        2066.512442
# 5          702.315036        2087.274320
# 7          716.062180        2128.130716
# 40         675.001973        2006.100131
# 10         695.896385        2068.198144
# 9          709.239119        2107.852638
# 4          700.578737        2082.114056
# 41         671.229033        1994.886984
# 26         711.037188        2113.196483

# %%
new_c_df.to_csv('ds_team_project1/data/indices/converted_indices_ny.csv')
top10_df.to_csv('ds_team_project1/data/indices/top10_indices_ny.csv')

# %%
c1_df = ds(0).append(ds(1)).append(ds(2)).append(ds(3)).append(ds(4)).append(ds(5)).append(ds(6)).append(ds(7)).append(ds(8)).append(ds(9)).append(ds(10)).append(ds(11)).append(ds(12)).append(ds(13)).append(ds(14)).append(ds(15)).append(ds(16)).append(ds(17)).append(ds(18)).append(ds(19)).append(ds(20)).append(ds(21)).append(ds(22)).append(ds(23)).append(ds(24)).append(ds(25)).append(ds(26)).append(ds(27)).append(ds(28)).append(ds(29)).append(ds(30)).append(ds(31)).append(ds(32)).append(ds(33)).append(ds(34)).append(ds(35)).append(ds(36)).append(ds(37)).append(ds(38)).append(ds(39)).append(ds(40)).append(ds(41))
c1_df
# Out:
#               city  cpi_index  groceries_index  rent_index  \
# 0        Cupertino  90.771683        81.583037   72.875806
# 1           Irvine  82.386102        76.194413   56.280840
# 2      Los Angeles  86.133244        77.044407   58.824536
# 3       Menlo Park  93.977449        80.575389   74.335789
# 4    Mountain View  92.168167        81.235487   74.454696
# 5        Palo Alto  92.545359        82.010727   74.698475
# 6        San Diego  70.341332        73.049624   43.984856
# 7    San Francisco  91.680596        80.822524   74.692788
# 8         San Jose  91.066061        81.536677   72.682975
# 9        San Mateo  90.770662        80.616279   74.103965
# 10     Santa Clara  91.066061        81.470962   72.539142
# 11    Santa Monica  85.076501        77.102652   60.078124
# 12       Sunnyvale  91.822840        81.235487   74.454696
# 13         Boulder  83.568113        76.483971   49.111902
# 14          Denver  82.244605        76.752203   49.196896
# 15      Washington  93.836346        81.851480   49.001171
# 16         Atlanta  77.718198        68.854906   38.340280
# 17         Chicago  72.080019        70.241123   38.405697
# 18    Indianapolis  77.090051        66.647750   28.785403
# 19          Boston  88.514779        78.680956   51.453236
# 20       Cambridge  86.280762        79.505881   49.447029
# 21     Kansas City  71.094511        67.679811   31.066225
# 22       St. Louis  69.695064        61.242228   24.833293
# 23     Minneapolis  85.709127        72.439484   38.807489
# 24       Charlotte  82.097416        62.563640   32.961310
# 25         Raleigh  78.483585        80.266450   32.978484
# 26        New York  86.298283        93.510587   60.012262
# 27      Cincinnati  65.578179        79.065930   28.061899
# 28       Cleveland  77.217366        70.440129   20.844567
# 29        Portland  74.661460        66.743408   39.231291
# 30    Philadelphia  78.299180        78.183653   42.829790
# 31          Austin  68.405718        64.669440   36.047757
# 32          Dallas  68.488081        65.833565   32.733576
# 33         Houston  85.966438        73.657618   41.244472
# 34       Nashville  74.540752        64.385727   34.919225
# 35           Plano  70.200123        65.531939   32.472845
# 36  Salt Lake City  63.369249        67.669293   28.313613
# 37          McLean  90.999141        81.164883   46.809601
# 38          Reston  94.339249        81.335266   47.752368
# 39        Richmond  75.067668        72.853065   34.345224
# 40        Bellevue  89.019226        77.359033   43.472161
# 41         Seattle  88.691158        79.775887   43.135382
#
#     restaurant_price_index
# 0                87.243631
# 1                78.198980
# 2                78.000157
# 3                89.816457
# 4                88.031205
# 5                88.249379
# 6                62.446598
# 7                89.976776
# 8                87.371573
# 9                89.119425
# 10               87.442844
# 11               77.547815
# 12               87.738712
# 13               78.815642
# 14               77.461746
# 15               90.288873
# 16               77.090357
# 17               80.153564
# 18               73.702173
# 19               83.130098
# 20               81.884711
# 21               70.254155
# 22               70.759031
# 23               80.433456
# 24               75.350432
# 25               69.745503
# 26               89.345361
# 27               69.337634
# 28               73.195953
# 29               74.425089
# 30               81.200002
# 31               72.457977
# 32               68.870081
# 33               79.022709
# 34               71.873793
# 35               70.428975
# 36               66.756199
# 37               89.459604
# 38               92.856903
# 39               70.981286
# 40               84.817357
# 41               84.343268

# %%
c1_df['cpi_single']=c1_df['cpi_index']/78.000157*1760.35
c1_df['cpi_family']=c1_df['cpi_index']/78.000157*4791.38
c1_df['rent_single']=c1_df['rent_index']/58.824536*(2075.33+1582.08)/2
c1_df['rent_family']=c1_df['rent_index']/58.824536*(3466.02+2722.98)/2
c1_df['groceries_single']=c1_df['groceries_index']/86.133244*241.80
c1_df['groceries_family']=c1_df['groceries_index']/86.133244*1209.02
c1_df['restaurant_single']=c1_df['restaurant_price_index']/77.044407*667.70
c1_df['restaurant_family']=c1_df['restaurant_price_index']/77.044407*1877.15
c1_df['occupation']=salary_df['occupation']
c1_df['salary']=salary_df['base_salary_md_pay']
c1_df['col_single']= c1_df['cpi_single'] + c1_df['rent_single']
c1_df['col_family']= c1_df['cpi_family'] + c1_df['rent_family']
c1_df['ds_single']= salary_df['base_salary_md_pay']/12 - c1_df['col_single']
c1_df['ds_family']= salary_df['base_salary_md_pay']/12 - c1_df['col_family']

# %%
c_df['state'] = o_df['state']
new_c_df = c_df[['state','city','occupation','salary','cpi_index','rent_index','restaurant_price_index','groceries_index','cpi_single','cpi_family','rent_single','rent_family','groceries_single','groceries_family','restaurant_single','restaurant_family','col_single','col_family','ds_single','ds_family']]
new_c_df.head()
# Out:
#         state           city          occupation     salary  cpi_index  \
# 0  California      Cupertino  Data Scientist, IT  125000.00  90.771683
# 1  California         Irvine  Data Scientist, IT   85295.36  82.386102
# 2  California    Los Angeles  Data Scientist, IT   86269.74  86.133244
# 3  California     Menlo Park  Data Scientist, IT   86400.00  93.977449
# 4  California  Mountain View  Data Scientist, IT  103042.00  92.168167
#
#    rent_index  restaurant_price_index  groceries_index   cpi_single  \
# 0   72.875806               87.243631        81.583037  1776.710454
# 1   56.280840               78.198980        76.194413  1612.576128
# 2   58.824536               78.000157        77.044407  1685.920447
# 3   74.335789               89.816457        80.575389  1839.458193
# 4   74.454696               88.031205        81.235487  1804.044402
#
#     cpi_family  rent_single  rent_family  groceries_single  groceries_family  \
# 0  5173.504824  1815.547656  3402.742620        231.442916       1157.198266
# 1  4695.571164  1402.118943  2627.884687        216.155931       1080.764418
# 2  4909.138427  1465.489775  2746.655808        218.567279       1092.820987
# 3  5356.216490  1851.920076  3470.912674        228.584322       1142.905493
# 4  5253.097034  1854.882407  3476.464745        230.456952       1152.268515
#
#    restaurant_single  restaurant_family   col_single   col_family  \
# 0         694.310990        2063.486363  3592.258110  8576.247444
# 1         622.330939        1849.562264  3014.695070  7323.455851
# 2         620.748647        1844.859706  3151.410221  7655.794235
# 3         714.786308        2124.338837  3691.378269  8827.129165
# 4         700.578737        2082.114056  3658.926809  8729.561779
#
#      ds_single    ds_family
# 0  6824.408556  1840.419223
# 1  4093.251596  -215.509184
# 2  4037.734779  -466.649235
# 3  3508.621731 -1627.129165
# 4  4927.906524  -142.728446

# %%
csv_path='ds_team_project1/data/salary/payscale_ds_salary.csv'
salary_df=pd.read_csv(csv_path)
salary_df.head()
# Out:
#    Unnamed: 0          occupation       state           city  \
# 0           0  Data Scientist, IT  California      Cupertino
# 1           1  Data Scientist, IT  California         Irvine
# 2           2  Data Scientist, IT  California    Los Angeles
# 3           3  Data Scientist, IT  California     Menlo Park
# 4           4  Data Scientist, IT  California  Mountain View
#
#    total_cash_comp_md_pay  base_salary_md_pay  bonus_md_pay  sample_size  \
# 0               130000.00           125000.00      14000.00            6
# 1                86955.19            85295.36       7500.00           16
# 2                85000.05            86269.74       4000.00           24
# 3                86400.00            86400.00      13265.57            5
# 4               114650.24           103042.00       9932.93           28
#
#                        last_reviewed
# 0  2018-01-10T14:56:09.8427599-08:00
# 1  2018-01-05T02:53:31.5132805-08:00
# 2  2018-01-10T14:46:11.6752289-08:00
# 3  2018-01-04T06:30:44.8894913-08:00
# 4  2018-01-10T14:46:32.5088419-08:00

# %%
top10_df=new_c1_df.nlargest(10,'salary')
top10_df
# Out:
#          state           city          occupation     salary  cpi_index  \
# 0   California      Cupertino  Data Scientist, IT  125000.00  90.771683
# 8   California       San Jose  Data Scientist, IT  117109.79  91.066061
# 5   California      Palo Alto  Data Scientist, IT  114109.51  92.545359
# 7   California  San Francisco  Data Scientist, IT  114060.42  91.680596
# 40  Washington       Bellevue  Data Scientist, IT  111968.75  89.019226
# 10  California    Santa Clara  Data Scientist, IT  109926.79  91.066061
# 9   California      San Mateo  Data Scientist, IT  104804.68  90.770662
# 4   California  Mountain View  Data Scientist, IT  103042.00  92.168167
# 41  Washington        Seattle  Data Scientist, IT  100529.55  88.691158
# 26    New York       New York  Data Scientist, IT   99199.95  86.298283
#
#     rent_index  restaurant_price_index  groceries_index   cpi_single  \
# 0    72.875806               87.243631        81.583037  2048.584744
# 8    72.682975               87.371573        81.536677  2055.228427
# 5    74.698475               88.249379        82.010727  2088.614026
# 7    74.692788               89.976776        80.822524  2069.097603
# 40   43.472161               84.817357        77.359033  2009.034344
# 10   72.539142               87.442844        81.470962  2055.228427
# 9    74.103965               89.119425        80.616279  2048.561700
# 4    74.454696               88.031205        81.235487  2080.101364
# 41   43.135382               84.343268        79.775887  2001.630324
# 26   60.012262               89.345361        93.510587  1947.626616
#
#      cpi_family  rent_single  rent_family  groceries_single  groceries_family  \
# 0   5575.907047  2265.523182  3833.675463        229.026301       1145.150447
# 8   5593.990047  2259.528562  3823.531480        228.896156       1144.499711
# 5   5684.860096  2322.185337  3929.558089        230.226947       1151.153780
# 7   5631.739638  2322.008541  3929.258918        226.891330       1134.475419
# 40  5468.257434  1351.438775  2286.879124        217.168347       1085.859698
# 10  5593.990047  2255.057155  3815.965049        228.711676       1143.577295
# 9   5575.844324  2303.703529  3898.283524        226.312344       1131.580441
# 4   5661.690047  2314.606879  3916.733965        228.050632       1140.272021
# 41  5448.104922  1340.969154  2269.162630        223.953129       1119.784166
# 26  5301.115810  1865.628366  3156.981021        262.510256       1312.572991
#
#     restaurant_single  restaurant_family   col_single   col_family  \
# 0          756.090867        2125.649201  4314.107926  9409.582510
# 8          757.199666        2128.766441  4314.756989  9417.521528
# 5          764.807114        2150.153773  4410.799362  9614.418185
# 7          779.777481        2192.240974  4391.106144  9560.998556
# 40         735.063732        2066.534200  3360.473119  7755.136558
# 10         757.817331        2130.502924  4310.285582  9409.955096
# 9          772.347304        2171.352016  4352.265229  9474.127848
# 4          762.916320        2144.838056  4394.708243  9578.424012
# 41         730.955075        2054.983254  3342.599478  7717.267552
# 26         774.305365        2176.856845  3813.254982  8458.096831
#
#       ds_single    ds_family
# 0   6102.558741  1007.084157
# 8   5444.392178   341.627639
# 5   5098.326471  -105.292351
# 7   5113.928856   -55.963556
# 40  5970.256048  1575.592608
# 10  4850.280252  -249.389263
# 9   4381.458105  -740.404514
# 4   4192.125091  -991.590679
# 41  5034.863022   660.194948
# 26  4453.407518  -191.434331

# %%
new_c1_df.to_csv('ds_team_project1/data/indices/converted_indices_la.csv')
top10_df.to_csv('ds_team_project1/data/indices/top10_indices_la.csv')
